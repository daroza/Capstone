# %%
import tweepy
from textblob import TextBlob

#from twitter_authentication import API_KEY, API_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET

consumer_key = '6SSi1lsTmqvtemFrL133s84xz'
consumer_secret = 'lLh4Fydd1ix6aZvXvpO9vHSM3CK7ItORfPNb90nc6gpy1YeDU9'
access_token ='753833979174719490-8HJT0iFhBWiktwiORZ8PlhPqVOA20G8'
access_token_secret = 'yM7KEYZbaBJN5OWExm4j11E4ZaSbIVEAaZd3BUDlKLGhD'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)
#public_tweets = api.search('vote')
# for tweet in public_tweets:
#     print(tweet.text)
#     analysis = TextBlob(tweet.text)
#     print(analysis.sentiment)
    
query = 'vote'
max_tweets = 1000
searched_tweets = [status for status in tweepy.Cursor(api.search, q=query).items(max_tweets)]

for tweet in searched_tweets:
    #print(tweet.text)
    analysis = TextBlob(tweet.text)
    #print(analysis.sentiment)
# Out:
# @diegosaurs_  did u vote
# Sentiment(polarity=0.0, subjectivity=0.0)
# @ithnkilvu15 how many times can u vote?
# Sentiment(polarity=0.5, subjectivity=0.5)
# -- don't show enough maturity to even be allowed to vote in the election
# Sentiment(polarity=0.0, subjectivity=0.5)
# RT @sinderbrand: For the 2nd time in a week, a Trump supporter has been arrested for trying to vote twice. (flashback to last week: https:/…
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
# Florida w/29 electoral votes.  48.5% pop vote for each candidate &amp; still going. So tight.  #ElectionNight
# Sentiment(polarity=-0.17857142857142858, subjectivity=0.2857142857142857)
# RT @thealakhras: Standing in line to vote this morning — got asked how long I plan on staying in “our country”. #IslamophobiaAtPolls
# Sentiment(polarity=-0.05, subjectivity=0.4)
# RT @KHOU: Man arrested in Fort Bend County for attempting to vote twice. https://t.co/ac7q17EmVK
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ladygaga: Listen up America ✌🏾✌🏿✌🏽✌🏼✌🏻Get in your car or put on your shoes + go out &amp; #Vote ! 🇺🇸 needs you!! #ElectionDay #Election2016…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Haha THEN DONT VOTE FOR HIM! You only have yourselves to blame. https://t.co/fbZoAmLZvw
# Sentiment(polarity=0.125, subjectivity=0.65)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/zBthFY9kWf
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @DonaldJTrumpJr: FOX NEWS EXIT POLL: 87% of voters believe my father is the true change candidate. #MAGA
#
# GO VOTE! #TRUMP
# Sentiment(polarity=0.4375, subjectivity=0.65)
# RT @whytruy: *casts vote for Hillary*
# Hillary: Thank you for your vot-
# Me: https://t.co/EjvxMWZD2c
# Sentiment(polarity=0.0, subjectivity=0.0)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/5Kr7cWBasP
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @TheVicStyles: IMPORTANT: if you live in 1 of these states you can register to vote TODAY at the polls. Don't let anything stop you. htt…
# Sentiment(polarity=0.2681818181818182, subjectivity=0.75)
# RT @JacobWhitesides: she got my vote 🇺🇸 https://t.co/D52v1HV4f4
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @danisnotonfire: they should model american democracy on eurovision and have each party candidate perform a song to decide who to vote f…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @laureIscastiIlo: me the majority of the election: idk i don't rlly like hillary that much but i guess she has my vote
# me today: https:/…
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @NiallOfficial: Wish I could vote today .. America get out and vote and do the right thing please
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# threw Hilary her lil vote &amp; called it a day😌 https://t.co/KFNAW3p10c
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @HillaryClinton: Don't stand still. Vote today: https://t.co/jfd3CXLD1s #ElectionDay #MannequinChallenge https://t.co/4KAv2zu0rd
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @worldnews_atv34: ทรัมป์คว้า Electoral Vote ไปแล้ว 24 เสียง คลินตันได้ไป 3 เสียง #bbc https://t.co/a740Lfxh5r
# Sentiment(polarity=0.0, subjectivity=0.0)
# @KDcalmdOwn I'm jus saying how the actual system "works" but our ppl fought tooth and nail for the right to vote not very many years ago...
# Sentiment(polarity=0.031135531135531136, subjectivity=0.34010989010989007)
# I cast my Heisman ballot for Lamar Jackson! Click the player you think deserves the @NissanUSA #HeismanHouse vote! https://t.co/RjM3FgmjpP
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @TheDemocrats: She's right — if you're in line when polls close, you can vote!
# https://t.co/ZKn8fJEh9z https://t.co/3hLGsZhcGl
# Sentiment(polarity=0.3571428571428571, subjectivity=0.5357142857142857)
# RT @_Latishhaaaa: I got a lump in my throat as I watched this , President Obama , you will be truly missed 😭😭 Continue his legacy , GO VOTE…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @AriMelber: Nevada law states that if voters are "waiting to vote" in line when polls close, "voting must continue" until they vote. (29…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @theNiqirtsuituq: 8.17 น. ฟลอริดา รัฐที่อาจเป็นตัวชี้ชะตา #Election2016 คลินตัน กับ ทรัมป์ สูสีมาก!
#
# Electoral vote มีถึง 29 คะแนน!
# http…
# Sentiment(polarity=0.0, subjectivity=0.0)
# @PARRILLABOSS
# Lana parrilla
# Bexana
# Bexilie
# Vote
# ALLY
# fav fav fav
# Sentiment(polarity=0.0, subjectivity=0.0)
# IF YOU HAVEN'T VOTED, GO RIGHT NOW AND VOTE FOR TRUMP! #MakeAmericaGreatAgain  #ElectionNight
# Sentiment(polarity=0.3571428571428571, subjectivity=0.5357142857142857)
# RT @MTVNews: REMINDER: if you're in line to vote when the polls close, they're legally required to let you vote.
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @realDonaldTrump: Don't let up, keep getting out to vote - this election is FAR FROM OVER! We are doing well but there is much time left…
# Sentiment(polarity=0.1625, subjectivity=0.6)
# Seriously though, you have no right to complain about how the government is run if you don't vote. #exerciseyourright #ElectionNight
# Sentiment(polarity=-0.23809523809523808, subjectivity=0.6011904761904762)
# @RicFlairNatrBoy write-in vote swings North Carolina on #ElectionNight. #MacauleyCulkin vote keeps New York blue. #HomeAlone #Vote2016
# Sentiment(polarity=0.06818181818181818, subjectivity=0.2772727272727273)
# I cast my Heisman ballot for Jabrill Peppers! Click the player you think deserves the @NissanUSA #HeismanHouse vote! https://t.co/qUBFDHNP5J
# Sentiment(polarity=0.0, subjectivity=0.0)
# If Florida remains this close and makes the difference, there is definitely going to be some big nasty vote count litigation.
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.5333333333333333)
# RT @Medievalists: Still time to vote - for your medieval Ruler! #ElectionDay https://t.co/Ss1r8MRb9e
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @_Latishhaaaa: I got a lump in my throat as I watched this , President Obama , you will be truly missed 😭😭 Continue his legacy , GO VOTE…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @MAHAMOSA: VOTE 4 a world of #green trees, crisp #air &amp; clean #oceans, no pain or suffering, no #homeless or hungry, of happiness &amp; heal…
# Sentiment(polarity=0.2791666666666667, subjectivity=0.4041666666666667)
# RT @_carolineotoole: If you vote Trump tomorrow, make sure explain to your gay, trans, female, black, Latina/o, and Muslim friends why they…
# Sentiment(polarity=0.18750000000000003, subjectivity=0.5180555555555556)
# RT @Hott_Carmel: When you suspect your wife might not actually vote for you on #ElectionDay https://t.co/2QonLlfKjj
# Sentiment(polarity=0.0, subjectivity=0.1)
# @maxpolk 115 vote difference now. Wow.
# Sentiment(polarity=0.1, subjectivity=1.0)
# RT @KatEdmiston: @LEngelhorn D's have to learn to vote in midterm elections!!!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @b3xxi123: @SubPixelYouTube I'd vote for you :P Prime Minister of Awesome! #SubPixForChange
# Sentiment(polarity=0.875, subjectivity=1.0)
# People who say their vote doesn't matter... Every vote matters.
# Sentiment(polarity=0.0, subjectivity=0.0)
# Id never vote for Hillary bc even though Trump isn't fucking better- SHE DOES NOT DESERVE TO BE KNOWN AS THE FIRST FEMALE PRESIDENT. PERIOD.
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# RT @nycjim: With 53 percent of the vote in, Clinton is holding a 6-point lead in North Carolina. https://t.co/zht2aOB0xO https://t.co/oBcMc…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @AC360: .@ananavarro: "It would be sweet, sweet justice if tonight it was the Latino vote that defeated Donald Trump" https://t.co/ZTdYJ…
# Sentiment(polarity=0.35, subjectivity=0.65)
# RT @SoneVIETNAMs: [VOTE] 2016 Asia Artist Award via AAA App https://t.co/RZrNeFd9PG
# Singer : SNSD (Currently #14)
# Actress : Yoona (Currentl…
# Sentiment(polarity=-0.375, subjectivity=0.7)
# Either way your vote will have a serious impact on the pantsuit industry.  #MyVote2016
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.6666666666666666)
# *Makes Election tweet because I want to be cool and get likes even tho I can't vote*
# Sentiment(polarity=0.35, subjectivity=0.65)
# RT @DonaldJTrumpJr: College voters might determine this election. Vote for a proven leader, not a corrupt politician. Politicians created t…
# Sentiment(polarity=0.25, subjectivity=1.0)
# RT @NiallOfficial: Wish I could vote today .. America get out and vote and do the right thing please
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/tHBVx3RjCM
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @JBieberProjeto: CINQUENTA RETWEETS AQUI RÁPIDO, JUSTIN TA PERDENDO FEIO, VOTEM!!
# BELIEBERS VOTE EMA
# #EMABiggestFansJustinBieber https:/…
# Sentiment(polarity=0.0, subjectivity=0.0)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/ibiu60vX3Q
# Sentiment(polarity=0.625, subjectivity=0.75)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/DD7jLK3xOi
# Sentiment(polarity=0.625, subjectivity=0.75)
# @Bethany_C7 the answer is Obama though so nice vote
# Sentiment(polarity=0.6, subjectivity=1.0)
# RT @KimberleiDavis: JUST IN: #DonaldTrump will win SC based on exit poll and vote analysis, @ABC News projects. #ElectionNight  https://t.c…
# Sentiment(polarity=0.8, subjectivity=0.4)
# RT @shelbypage420: If you didn't vote you best keep your mouth shut after you find out who wins and you're not happy
# Sentiment(polarity=0.3, subjectivity=0.5)
# RT @FoxNews: National popular vote - with 8% in, @realDonaldTrump leads @HillaryClinton 50.2% to 46.6%. #ElectionNight #FoxNews2016 https:/…
# Sentiment(polarity=0.6, subjectivity=0.9)
# RT @Kalenpray: Don't forget to Vote! https://t.co/179C0gMIvu
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @_Haleyy_Nicolee: If you haven't voted it's not too late! Make sure you cast your vote! But not for killary of course! #MakeAmericaGreat…
# Sentiment(polarity=0.203125, subjectivity=0.7444444444444445)
# Oh thank G'mork, @MarkDoesStuff is uploading his videos for the week, I'll have something to distract me from watching vote counts.
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ladygaga: RT and spread this message Monsters! It's election KRUNCHTime and EVERY VOTE counts! #ElectionDay #Elections2016 #GoVote #Vot…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @HereIsGina: STAY IN LINE. MY PEOPLE. MY WARRIORS.  IF YOU ARE IN LINE TO VOTE, STAY IN LINE.
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Calum5SOS: To my American friends, I love your country. If I could vote, I would... Please invest in your future and VOTE
# Sentiment(polarity=0.16666666666666666, subjectivity=0.24166666666666667)
# RT @reynososo_: A vote for the Cross Counter party is a vote for #esports @gootecks https://t.co/cdcliSSJzf
# Sentiment(polarity=0.0, subjectivity=0.0)
# how the hell is this election so close?? who the hell would vote for Trump??
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @whytruy: vote hillary clinton🙌🏽 idc if she a liar yall boyfriends lie to yall everyday &amp; yall still fw them so gone head &amp; vote for her
# Sentiment(polarity=-0.2, subjectivity=0.6)
# 5 different broadcasts. 5 different electoral vote totals. #callingstateswith3%reporting
# Sentiment(polarity=0.0, subjectivity=0.6)
# u shouldn't be allowed to vote if you're older 60 https://t.co/hYuMBAySFd
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
# RT @NOTSportsCenter: BREAKING: In the first unanimous vote in election history, voters have voted to impeach Roger Goodell and replace him…
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# RT @C_Shaughnessy: Maya..... Guardian of Democracy
# #IVOTED #electionday #Imwithher #HillaryClintonforpresident
# #Vote https://t.co/B2Slj4f…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ThereGoShane: Can I vote to have Chris Christie out
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @RaeSremmurd: 🇺🇸Go vote for her🇺🇸 https://t.co/VSqC8Qpc6S
# Sentiment(polarity=0.0, subjectivity=0.0)
# @courtcourt1417 @Logann501 I wasn't disrespecting yours. I was stating my opinion. I dislike corruption but have no problem with your vote.
# Sentiment(polarity=0.0, subjectivity=0.0)
# @HillaryClinton I'M ROOTING FOR YOU HILLARY!!! Feeling really nervous #ImWithHer #Vote #VoteForHillary
# Sentiment(polarity=0.2, subjectivity=0.2)
# Florida vote 70% yes on medicinal marijuana use. Good.
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# RT @elizabeth2863: Clinton leads Bexar County early vote with 53 % to Trump's 41 % https://t.co/XU4PEk3ZqP via @mySA #Election2016 and #Ele…
# Sentiment(polarity=0.1, subjectivity=0.3)
# RT @GOP: I voted Republican.
#
# RT if you're ready to take back the White House &amp; keep our majorities in the House &amp; Senate: https://t.co/W5Y…
# Sentiment(polarity=0.06666666666666667, subjectivity=0.16666666666666666)
# RT @GillianNJones: Who has your vote? #Fox4Elections @FOX4
# Sentiment(polarity=0.0, subjectivity=0.0)
# @seanslavengreen @makenzielee_ yeah and also we will be able to vote in the next election so we need to become educated about it now
# Sentiment(polarity=0.25, subjectivity=0.3125)
# RT @NoHoesGeorge: Vote Corey back in the house
# Sentiment(polarity=0.0, subjectivity=0.0)
# if u can vote i hope u did. 💙
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @JasonKander: The after work rush is starting. Remember, if you're in line by 7 you get to vote. #mosen https://t.co/s0RlbfBUD6
# Sentiment(polarity=0.0, subjectivity=0.1)
# RT @nycjim: Right now, the Florida votes totals for Clinton and Trump are closer than the vote totals for Bush and Gore. https://t.co/yzQb9…
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# RT @lucasgreg: Daughter's first vote. Proud moment, important moment. #hervotematters #herlifematters #proudpapa https://t.co/zKXHnpKdHT
# Sentiment(polarity=0.4833333333333334, subjectivity=0.7777777777777777)
# RT @HappyDiscusser: #ImWitHer #Election2016, Please #vote, #USElection and vote wisely Americans. Nervous friends in Europe. https://t.co/n…
# Sentiment(polarity=0.7, subjectivity=0.9)
# @jaycee_davisson go vote 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# Contemplating - people that state "If you don't vote, you don't have the right to complain" really make me laugh-... https://t.co/bUYwJZjHcg
# Sentiment(polarity=0.2619047619047619, subjectivity=0.2785714285714286)
# If the hispanic vote is so high in Florida, why at 88% does trump lead?
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)
# RT @leedsgarcia: Looks like Latinos &amp; Asians have doubled their vote share in Georgia.  It's only a matter of time. #immigration #Election2…
# Sentiment(polarity=0.0, subjectivity=1.0)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/EaTqxknPVd
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @whytruy: *casts vote for Hillary*
# Hillary: Thank you for your vot-
# Me: https://t.co/EjvxMWZD2c
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @josephtbeatty: I know nothing about politics but if you say the U.S. is going to shit if Trump is president and then vote for a crimina…
# Sentiment(polarity=-0.2, subjectivity=0.8)
# I've put up with both of these candidates for over a year &amp; you're telling me I can't watch them react to the Florida vote coming in?
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @nycjim: Right now, the Florida votes totals for Clinton and Trump are closer than the vote totals for Bush and Gore. https://t.co/yzQb9…
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# RT @ScottWesterfeld: IF YOU
#     💁🏼
# ARE IN LINE
#  🚶🏾🚶🏾🚶🏾🚶🏾🚶🏾🚶🏾🚶🏾
# WHEN THE POLLS
# CLOSE
#   🗝
# THEY
#   👮🏽👮🏻
# ARE LEGALLY REQUIRED
#   ⚖⚖⚖⚖
# TO LET YOU…
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @wikileaks: It’s ignorant to vote for Hillary Clinton without reading WikiLeaks
# https://t.co/Tiywc9Nrgr https://t.co/c0QaJW4hCi
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @laureIscastiIlo: me the majority of the election: idk i don't rlly like hillary that much but i guess she has my vote
# me today: https:/…
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @HillaryClinton: Remember, if you are in line before polls close, you can vote! Have a question? Call 1-917-444-5915. https://t.co/2MVKO…
# Sentiment(polarity=0.0, subjectivity=0.0)
# i just wanna know why it's not done by popular vote...it makes no sense
# Sentiment(polarity=0.6, subjectivity=0.9)
# RT @elizabethforma: This morning I proudly cast my vote for @HillaryClinton to be the next President of the United States. #ImWithHer https…
# Sentiment(polarity=0.4, subjectivity=0.5)
# RT @_carolineotoole: If you vote Trump tomorrow, make sure explain to your gay, trans, female, black, Latina/o, and Muslim friends why they…
# Sentiment(polarity=0.18750000000000003, subjectivity=0.5180555555555556)
# Let’s get out and vote … let’s make our voices heard … we’ve been given the right to choose between a douche and a turd …
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# RT @WhereisADTR: Alex is nominated for Best International Rock Drummer in @RhythmMagazine’s Best in Drums 2016 Poll! Go vote now at https:/…
# Sentiment(polarity=0.6666666666666666, subjectivity=0.19999999999999998)
# @deeds6969 To bad you can't have dual citizenship and vote today!
# Sentiment(polarity=-0.8749999999999998, subjectivity=0.6666666666666666)
# RT @greysonchance: To every American 18+...
# Go VOTE tomorrow! We have a chance to stop Donald Trump from ever stepping into the Oval Office…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @LaLaSizaHands89: Omw to vote honey!! Yall ready?? I am!! #Vote #VoteOrDie #ImWithHer Song by: @bigfreedia https://t.co/IGHvk2BcA1
# Sentiment(polarity=0.3125, subjectivity=0.5)
# RT @NiallOfficial: Wish I could vote today .. America get out and vote and do the right thing please
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Come on Florida be a bro and vote trump! #neverher
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @HoustonChron: BREAKING: Fort Bend SO said they arrested a man for trying to vote twice. Man claimed he worked for Trump &amp; was "testing…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @_carolineotoole: If you vote Trump tomorrow, make sure explain to your gay, trans, female, black, Latina/o, and Muslim friends why they…
# Sentiment(polarity=0.18750000000000003, subjectivity=0.5180555555555556)
# RT @Phil_Lewis_: Susan B. Anthony: Women should be allowed to vote! Suffrage is the pivotal right.
#
# Blacks: What about us?
#
# Susan B. Anthon…
# Sentiment(polarity=0.39285714285714285, subjectivity=0.6678571428571429)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC
# https://t.co/MIXG185rp5
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @RevDrBarber: Stay in line. Stay strong. Vote. Don't get discouraged. Pls RT #WeBetterVote
# Sentiment(polarity=0.4333333333333333, subjectivity=0.7333333333333333)
# RT @Pamela_Moore13: Another arrest made on an illegal alien trying to vote here in San Antonio. Be on the lookout! https://t.co/Ez3H3AFw5G
# Sentiment(polarity=-0.28750000000000003, subjectivity=0.4166666666666667)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/rsFTcjLm8W
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @StoneColdTruth: https://t.co/8LhXOqKPqO Citizens Exit Polling Shows Florida at 60% for Trump.
# Overall, trump winning with projected 57%…
# Sentiment(polarity=0.25, subjectivity=0.375)
# RT @Calum5SOS: To my American friends, I love your country. If I could vote, I would... Please invest in your future and VOTE
# Sentiment(polarity=0.16666666666666666, subjectivity=0.24166666666666667)
# The majority of this state wants Trump to be President, but we can't even vote on casino gaming....
# Sentiment(polarity=0.2, subjectivity=0.1)
# RT @FortHaceCosas: VOTE THE COMMANDER TO VIAJAR GRATIS A MAIAMEE https://t.co/jackXKYTXo
# Sentiment(polarity=0.0, subjectivity=0.0)
# The amount of Trump support I have seen in Florida + the large amount of people in Florida who I know didn't vote...idk.
# Sentiment(polarity=0.21428571428571427, subjectivity=0.42857142857142855)
# RT @Shupette: Why are we still allowing Florida to vote?
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @davidSrauf: Early vote totals from Bexar have Dems ahead against two GOP TX House incumbents: #HD117 #HD118 #txlege https://t.co/YazMjV…
# Sentiment(polarity=0.1, subjectivity=0.3)
# Watching Florida go back and forth between Clinton and Trump is so nerve wrecking. Really shows that your vote does count.
# Sentiment(polarity=0.1, subjectivity=0.1)
# RT @JimHarris: WOW! Clinton Now Leads Trump in Electoral College Vote 68 To 37 As Of 8:01pm #ElectionNight #Election2016 #uspoli via @GMA h…
# Sentiment(polarity=0.125, subjectivity=1.0)
# RT @berklyy_marie: PSA: this election is different, if you plan on voting for Hillary, you will vote WEDNESDAY instead of tomorrow. RT TO S…
# Sentiment(polarity=0.0, subjectivity=0.6)
# RT @DanaiGurira: Happy Election Day!
# Make sure your voice is heard!
# Vote!
# #ImWithHer.
# #TheFutureisFemale https://t.co/s6XK0ZYDzt
# Sentiment(polarity=0.890625, subjectivity=0.9444444444444444)
# RT @ShawnMWorId: I vote @ShawnMendes for New Artist Of The Year Un-leashed by @TMobile #AMAs
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# One of the few things I like about Jersey we always vote blue
# Sentiment(polarity=-0.1, subjectivity=0.1)
# RT @theNiqirtsuituq: 8.12 น. #Election2016 นับ electoral vote ไป 14 รัฐ
# - คลินตัน 68
# - ทรัมป์ 48
#
# ใครถึง 270 ก่อน ได้เป็นประธานาธิบดี
# https…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @VandamBodyslam: Couldn't vote (legally) so I freestyled my vote !!🗣
# #ElectionNight #MyVote2016 #Election2016 Prod by @MgDaBadguy561 htt…
# Sentiment(polarity=0.3125, subjectivity=0.2)
# @ronnieglassberg @theobserver  my problem with NC voters, vote for popularity then 4 years later we vote the other way,  always wait/see
# Sentiment(polarity=-0.0625, subjectivity=0.1875)
# I'll be so fucking salty if SHINee would not win this. Vote for SHINee!! #ElectionNight
# Sentiment(polarity=-0.55, subjectivity=0.6000000000000001)
# African-American voters @NBCNews reports that the #Trump campaign is counting that U will not vote. Get out there &amp; vote #HillaryClinton Plz
# Sentiment(polarity=0.0, subjectivity=0.0)
# holy crap NBC's florida chart just showed a 28 vote difference in the state
# Sentiment(polarity=-0.8, subjectivity=0.8)
# RT @thehill: JUST IN: Trump supporter arrested after trying to vote twice to ‘test the system’ https://t.co/4ZDFOHdnYs https://t.co/a62kxGm…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Make the right decision &amp; vote for Trump! #Trump 🇺🇸 Make America Great Again ❤️
# Sentiment(polarity=0.5785714285714285, subjectivity=0.6428571428571428)
# RT @DepressedDarth: Vote for me and together we can rule the galaxy #ElectionNight https://t.co/isfFH8hxLA
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @LeslieMac: Ya girl Susan was an zealous RACIST who made it a point in her push for women's vote  to ensure everyone knew where she stoo…
# Sentiment(polarity=0.0, subjectivity=0.0)
# I did the vote!
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @MaryCaitlinByrd: If you're standing in line to vote when the polls close, you can still vote. If you aren't in line, you're out of luck…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @EmmaAlpaca: FLORIDA. VOTE. TRUMP.
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @SupermanHotMale: If you are still in line to vote, STAY PUT, they have to let you vote...
# IT MATTERS!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Bdell1014: It's so crazy how the entire nation can vote for a President &amp; we find out that day but you can't even get an exam back afte…
# Sentiment(polarity=-0.19999999999999998, subjectivity=0.5083333333333333)
# dont underestimate that latino vote 👌 https://t.co/kIZPamFKG7
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @greatestjubilee: reminder your vote does matter https://t.co/ygz5PNLdH6
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @StoranYSL: If you're voting, TAKE IT SERIOUSLY, don't try to be funny to gain retweets and waste your vote, don't be like these stupid…
# Sentiment(polarity=-0.09444444444444444, subjectivity=0.5555555555555555)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/xCDjNSLFew
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @whytruy: *casts vote for Hillary*
# Hillary: Thank you for your vot-
# Me: https://t.co/EjvxMWZD2c
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @_Latishhaaaa: I got a lump in my throat as I watched this , President Obama , you will be truly missed 😭😭 Continue his legacy , GO VOTE…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @PapiiQuann_: Before you vote, watch this please https://t.co/ObIeqP67w9
# Sentiment(polarity=0.0, subjectivity=0.0)
# #Florida get out and vote! #FloridaVote
# Sentiment(polarity=0.0, subjectivity=0.0)
# florida has a 115 vote difference rn if that does show you how much every vote counts then idk what will.… https://t.co/qLl5q7YZ10
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @brujaaverde: Trump couldn't even vote for himself because his mother was born in Scotland you past-ripe banana lookin bitch https://t.c…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @TeamMcMullin: .@LindseyGrahamSC casts his vote for @Evan_McMullin https://t.co/C6dycKMUdU #utpol #utah #McMullinFinn
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @DonaldJTrumpJr: Young people across the country are rising up voting for Trump. Young democrats have been amazing! Thank you for your v…
# Sentiment(polarity=0.3166666666666667, subjectivity=0.5666666666666668)
# RT @HillaryClinton: Remember, if you are in line before polls close, you can vote! Have a question? Call 1-917-444-5915. https://t.co/2MVKO…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @LegionHoops: Just a reminder on who to vote for today. https://t.co/x0Zcj0TlOJ
# Sentiment(polarity=0.0, subjectivity=0.0)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/xYx2OhtYQn
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @patrickhumps: If Hillary loses the election by like 1 vote I'm blaming it on the person who wrote in Harry Styles on their ballot
# Sentiment(polarity=-0.3, subjectivity=0.1)
# RT @breakingnorfolk: CNN reporting 85% of the vote in for #Florida, 48.5% Clinton, 48.5% Trump
#
# Why do you always do this Florida? #results…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @patrickhumps: If Hillary loses the election by like 1 vote I'm blaming it on the person who wrote in Harry Styles on their ballot
# Sentiment(polarity=-0.3, subjectivity=0.1)
# RT @RaeSremmurd: 🇺🇸Go vote for her🇺🇸 https://t.co/VSqC8Qpc6S
# Sentiment(polarity=0.0, subjectivity=0.0)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/7yT3b6E0au
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @RyanLizza: Worth repeating: Trump is going to do worse with the white vote than Romney did.
# Sentiment(polarity=-0.03333333333333335, subjectivity=0.2333333333333333)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/sKIWVuBSuv
# Sentiment(polarity=0.0, subjectivity=0.0)
# Just like Trump supporters ask how we could vote for Hillary, I look at you exactly the same way... END of the day, vote for what you want
# Sentiment(polarity=0.125, subjectivity=0.1875)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/HLcwMVWiMK
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @HereIsGina: STAY IN LINE. MY PEOPLE. MY WARRIORS.  IF YOU ARE IN LINE TO VOTE, STAY IN LINE.
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @joanwalsh: Guy on @BrianLehrer says he dedicated his vote to Hillary to his girlfriend, as an engagement gift. (She convinced him HRC w…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @heytana: If you're a college student or recent graduate you better vote for @realDonaldTrump &amp; @mike_pence proven leaders not a corrupt…
# Sentiment(polarity=0.25, subjectivity=0.375)
# @realDonaldTrump yes vote Hillary!
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @glockjawz: my polling place ran out of English stickers but we bilingual out here fam 😂🤘🏽 MAKE SURE YALL GO VOTE!!!! https://t.co/ViVzz…
# Sentiment(polarity=0.5, subjectivity=0.4444444444444444)
# RT @HaydenShipwreck: If you vote Hillary, you probably drink unsweet tea, date your sister, and delete stuff off your phone so your parents…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @FBCSO: Arrest: We can confirm 1 arrested for attempting to vote a second time. Claimed he worked for Trump and was testing the system.
# Sentiment(polarity=-0.025, subjectivity=0.0)
# RT @vickto_willy: Hillary: "Vote for me."
# Me mimicking her: "Vote for m- SHUT UP. You know damn well you the only option." https://t.co/0OA…
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @jonsansa: Who would you vote for to be President? (hypothetically speaking)
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Nudah: GO:OD Morning. 🌞
#
# don't forget to vote for PewDiePie today at the polls guys ❤️ #MakeAmericaGreatAgain
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @nycjim: Right now, the Florida votes totals for Clinton and Trump are closer than the vote totals for Bush and Gore. https://t.co/yzQb9…
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/s7kSfKZbOQ
# Sentiment(polarity=0.0, subjectivity=0.0)
# IF UR LIVING IN FLORIDA // VOTE FOR @realDonaldTrump
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @FnA_Wolverines: Who's your vote✅ for Player of the Game vs #Maryland❓"LIKE" for 4️⃣De'Veon Smith RT for 3️⃣Wilton Speight #goblue #fann…
# Sentiment(polarity=-0.4, subjectivity=0.4)
# RT @LaLaSizaHands89: Omw to vote honey!! Yall ready?? I am!! #Vote #VoteOrDie #ImWithHer Song by: @bigfreedia https://t.co/IGHvk2BcA1
# Sentiment(polarity=0.3125, subjectivity=0.5)
# RT @KimberleiDavis: JUST IN: #DonaldTrump will win SC based on exit poll and vote analysis, @ABC News projects. #ElectionNight  https://t.c…
# Sentiment(polarity=0.8, subjectivity=0.4)
# RT @ThatNiggle: Vote or Die🇺🇸 #ElectionDay https://t.co/m8JoMv1cnb
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @richchigga: please do not vote for donald trump so i can come to america
# Sentiment(polarity=0.0, subjectivity=0.0)
# IF CAPTAIN AMERICA CAN VOTE FOR HILLARY SO CAN YOU https://t.co/cV8IBGfcVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @MTVNews: REMINDER: if you're in line to vote when the polls close, they're legally required to let you vote.
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @DepressedDarth: Vote for me and together we can rule the galaxy #ElectionNight https://t.co/isfFH8hxLA
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Totalbiscuit: Go vote, then we can get this election over with and stop being colossal fuccbois to each other.
# Sentiment(polarity=0.0875, subjectivity=0.5875)
# florida pls vote trump
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @WhispersNewsLTD: Clinton Pulls Up In Pickup To Bring Illegal Mexicans To Vote https://t.co/AWBqOZg2rp https://t.co/dKCyxk7b4z
# Sentiment(polarity=-0.5, subjectivity=0.5)
# RT @aminawadud: #MyMuslimVote lets Muslims speak for themselves — finally https://t.co/lg9RwCgz0c via @voxdotcom
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @troyross_4: I thought trump had no chance at becoming president but it's really people out here that are dumb enough to vote for him...
# Sentiment(polarity=0.06875, subjectivity=0.5125)
# RT @heartouthealys: women did not fight for the right to vote for women in 2016 to vote for a man who wants to take away women's rights
# Sentiment(polarity=0.24285714285714285, subjectivity=0.31785714285714284)
# RT @screenwriterl: Keep voting California. No more paid politicians. Vote Trump. He doesn't want paid, and he can't b bought. R Guns R coun…
# Sentiment(polarity=-0.25, subjectivity=0.5)
# RT @EricHarmeyer1: why are people acting like it's against the law to not vote? It's okay to not vote!!
# Sentiment(polarity=0.390625, subjectivity=0.25)
# RT @Gabbienain: When you trust your wife to vote for you, but not really. https://t.co/tLprW7iXI3
# Sentiment(polarity=-0.1, subjectivity=0.2)
# I hope all of you went to vote !!! I just voted !!!! https://t.co/yEwEQdPjTe
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @KimberleiDavis: JUST IN: #DonaldTrump will win SC based on exit poll and vote analysis, @ABC News projects. #ElectionNight  https://t.c…
# Sentiment(polarity=0.8, subjectivity=0.4)
# RT @MartinPoile: BREAKING: 25 year old, London-based-male's tweet urging his 1127 British followers not to vote Trump swings election in th…
# Sentiment(polarity=0.05, subjectivity=0.1)
# RT @Shelovesmeechie: YALL NEED TO VOTE HILLARY BEFORE TRUMP WINS!!!!!! https://t.co/xqQIdmnz8D
# Sentiment(polarity=1.0, subjectivity=0.2)
# my grandpa went to vote with a trump hat on &amp; the lady told him to take it off &amp; he said "fuck you" &amp; walked away🤔
# Sentiment(polarity=-0.4, subjectivity=0.6)
# RT @nycjim: Right now, the Florida votes totals for Clinton and Trump are closer than the vote totals for Bush and Gore. https://t.co/yzQb9…
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# RT @CBSNews: Here's the current electoral vote map. The white states represent toss-up races. https://t.co/H9n7JKbYS7 #Election2016 https:/…
# Sentiment(polarity=0.0, subjectivity=0.2)
# NASTY WOMEN &amp; so proud❤️Don't forget how beautiful it is that this whole group of ladies had the right to vote toda… https://t.co/0dSEwtKgaP
# Sentiment(polarity=0.08392857142857142, subjectivity=0.7339285714285714)
# @JessicaDrown Vote for Jesus
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @TomiLahren: Millennials, do you trust government? Then why would you vote for the woman dedicated to making it bigger?! #MAGA
# Sentiment(polarity=0.0, subjectivity=0.5)
# RT @NciszivaTk: Ohio, stay in line. Don't leave until you vote. #OHHillYes
# Sentiment(polarity=0.0, subjectivity=0.0)
# https://t.co/CNqugyAxn5 vote for me
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @G_Eazy: PLEASE GO OUT AND VOTE WHATEVER YOU DO, THIS COULD BE THE MOST IMPORTANT ELECTION OF OUR LIVES #imwithher #fuckdonaldtrump
# Sentiment(polarity=0.45, subjectivity=0.75)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/cxZOSkj7gB
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @TxRaveFam: Presidential Election Vote:
# ⚪️Hillary Clinton
# ⚪️Donald Trump
# ⚪️Kanye West
# 🔘Marshmello
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @RNRFlorida: BREAKING: Over 40 Illegals Arrested For Trying to Vote in California https://t.co/PmQ6mkCp2N #RedNationRising #VoterFraud #…
# Sentiment(polarity=0.0, subjectivity=0.0)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/y82P1S1yM8
# Sentiment(polarity=0.0, subjectivity=0.0)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/6JNmCK2Fhj
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @WorIdStarLaugh: I got a lump in my throat as I watched this , President Obama ,you will be truly missed 😭 Continue his legacy!! VOTE ht…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @latinalilly: electoral vote from kansas is for sure going to be for trump because my state is trash
# Sentiment(polarity=0.5, subjectivity=0.8888888888888888)
# Trump won Alabama anyway I knew my vote didn't matter..
# Sentiment(polarity=0.0, subjectivity=0.0)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/MEa0ZxLjS6
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @BrockVergakis: This Navy veteran took a bus and walked 3 blocks on crutches to vote for Clinton in Norfolk. Says Trump doesn't know mor…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Gabbienain: When you trust your wife to vote for you, but not really. https://t.co/tLprW7iXI3
# Sentiment(polarity=-0.1, subjectivity=0.2)
# RT @nicolettegum: This Florida vote is making me sick
# Sentiment(polarity=-0.7142857142857143, subjectivity=0.8571428571428571)
# RT @JohnFromCranber: It's All About Turnout. Typically Only About 1/2 Vote. If All the Folks  Who Prefer Trump Over Hillary Vote - WE WIN I…
# Sentiment(polarity=0.4, subjectivity=0.7)
# RT @nycjim: With 53 percent of the vote in, Clinton is holding a 6-point lead in North Carolina. https://t.co/zht2aOB0xO https://t.co/oBcMc…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @sinderbrand: For the 2nd time in a week, a Trump supporter has been arrested for trying to vote twice. (flashback to last week: https:/…
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
# 10 MINS until polls close in Ark. If you’re in line by 7:30 p.m., you’re allowed to vote. #Election2016 Updates:… https://t.co/xXnK58w9OX
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @DonaldJTrumpJr: DRUDGE: ELECTION WILL BE DECIDED BY EVENING VOTERS
#
# GET OUT AND VOTE! Find 5 others. This is our chance to take back Am…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Last year my social studies teacher made a polling place in his classroom and we all got to vote in voting booths and all. It was so cool😂❤️
# Sentiment(polarity=0.016666666666666666, subjectivity=0.06666666666666667)
# Confused why people are flipping out at people getting creative with their write-in options on the ballot. One vote wont change anything
# Sentiment(polarity=0.04999999999999999, subjectivity=0.85)
# RT @ElOvulo: "El triunfo de Ricardo Rosselló es tuyo boricua."
#
# Mío no. Yo no voté por esa mierda.
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @michellemalkin: If you are getting freaked out by the "Key Vote Alert" bulletins, you are still watching CNN.
# Why are you watching CNN?
# Sentiment(polarity=0.0, subjectivity=1.0)
# @KyleAllenMusic Its interesting how most counties vote republican, even in states that democrats win.
# Sentiment(polarity=0.6, subjectivity=0.4666666666666666)
# RT @hellomaleni: The difference in Florida is by less than 5,000 votes. Don't ever tell me your vote doesn't count. #ElectionNight
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.06666666666666667)
# @DustinHurst Can felons vote in Florida?
# Sentiment(polarity=0.0, subjectivity=0.0)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/ztikxp1jET
# Sentiment(polarity=0.0, subjectivity=0.0)
# Guys I'm not going to stream but what r u guys going to vote for?
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @_carolineotoole: If you vote Trump tomorrow, make sure explain to your gay, trans, female, black, Latina/o, and Muslim friends why they…
# Sentiment(polarity=0.18750000000000003, subjectivity=0.5180555555555556)
# RT @Harry_Styles: "Why would I vote? I don't like either of you."
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @CBCToronto: BREAKING: Toronto city council approves SmartTrack funding plan https://t.co/zB25Tkmj2i #topoli https://t.co/CYheJrER96
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @qwertyoruiopz: trump got a 30 vote lead in florida you can’t make this shit up
# Sentiment(polarity=-0.2, subjectivity=0.8)
# RT @onlyagbr: *VALID VOTE*
#
# WORKING ARIANATORS
#
# @twentyonepilots for Favorite Artist - Alternative Rock #AMAs https://t.co/6mbY8PxDir
# Sentiment(polarity=0.5, subjectivity=1.0)
# RT @RandyRRQuaid: If you haven't voted @RandyRRQuaid needs you to get in line. when polls close, you can vote to #draintheswamp https://t.c…
# Sentiment(polarity=0.0, subjectivity=0.0)
# FL VOTE TRUMP 29 votes behind the 👹
# Sentiment(polarity=-0.4, subjectivity=0.7)
# RT @TIME: Donald Trump says it’s 'sad' George W. Bush didn’t vote for him https://t.co/YQ2hX69x3w
# Sentiment(polarity=-0.5, subjectivity=1.0)
# rocked that vote #thefutureisfemale https://t.co/rtdDPl2dnK
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @KimberleiDavis: JUST IN: #DonaldTrump will win SC based on exit poll and vote analysis, @ABC News projects. #ElectionNight  https://t.c…
# Sentiment(polarity=0.8, subjectivity=0.4)
# RT @CNN: George W. Bush did not vote for Hillary Clinton, despite what Rush Limbaugh claims https://t.co/Bo5QD9Fff9 #ElectionNight https://…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Chris_Benjiii: If you didn’t vote and you live in the state of Florida, you an idiot cuz ur vote def counts lol
# Sentiment(polarity=0.04545454545454545, subjectivity=0.6666666666666666)
# RT @brandonjaymes1: I wasn't old enough to vote in the primaries so none of this is my fault
# Sentiment(polarity=0.05, subjectivity=0.35)
# RT @POTUS: Today, progress is on the ballot. Go vote - then make sure your friends, your family, and everyone you know votes too.
# Sentiment(polarity=0.5, subjectivity=0.8888888888888888)
# Vote I did!
# #ivoted #election2016 @Kelsey__Long @kenseylong @KirstyEllinger https://t.co/zIJbDupxv3
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @laureIscastiIlo: me the majority of the election: idk i don't rlly like hillary that much but i guess she has my vote
# me today: https:/…
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @gayevak: imagine wasting a vote for something as stupid as this... can't relate! https://t.co/eYBb9jLfy8
# Sentiment(polarity=-0.9999999999999999, subjectivity=1.0)
# EARLY VOTE
# Harris: Clinton 54-43
# Dallas: Clinton 61-35
# Tarrant: Trump 53-43
# Bexar: Clinton 53-41
# Travis: Clinton 68-27
# Denton: Trump 59-37
# Sentiment(polarity=0.1, subjectivity=0.3)
# RT @lauraolson: Pat Toomey casts his ballot for Donald Trump, saying he "struggled" with decision.  https://t.co/DplAcCCIXd
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @reynoldspool: LOOK AT HOW CUTE HE IS SITTING THERE VOTING FOR HILLARY WHEN HE SHOULD BE VOTING FOR HIMSELF ALL YALL HAD TO DO WAS VOTE…
# Sentiment(polarity=0.5, subjectivity=1.0)
# RT @LawyersComm: Any voter w/ kids being kept from bringing their children into the booth should call our #ProtectOurVote hotline: 866 OUR…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @tharealversace: REASONS WHY YOU HAVE TO VOTE FOR HILLARY #VOTEHILLARY 😭😭🙏🏾 https://t.co/eLzD2pVSw1
# Sentiment(polarity=0.0, subjectivity=0.0)
# I cast my Heisman ballot for Lamar Jackson! Click the player you think deserves the @NissanUSA #HeismanHouse vote!
# https://t.co/vKozxilSrA
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @BandzUpDee: Vote Hillary Clinton idc if she a liar y'all boyfriends lie to y'all everyday and y'all still fw them so VOTE HILLARY BITCH…
# Sentiment(polarity=-0.2, subjectivity=0.6)
# RT @Gabbienain: When you trust your wife to vote for you, but not really. https://t.co/tLprW7iXI3
# Sentiment(polarity=-0.1, subjectivity=0.2)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/q5SKTrzECA
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @seanhannity: Florida Panhandle - GO VOTE!
# Sentiment(polarity=0.0, subjectivity=0.0)
# I love living in a purple state where my vote actually matters. #nottennessee
# Sentiment(polarity=0.25, subjectivity=0.35)
# RT @mike_pence: Thank you Indiana for making our state first on the board to vote to Make America Great Again! @realDonaldTrump
# Sentiment(polarity=0.625, subjectivity=0.5416666666666666)
# I cast my Heisman ballot for Lamar Jackson! Click the player you think deserves the @NissanUSA #HeismanHouse vote! https://t.co/fI53jyOWAE
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @reynoldspool: LOOK AT HOW CUTE HE IS SITTING THERE VOTING FOR HILLARY WHEN HE SHOULD BE VOTING FOR HIMSELF ALL YALL HAD TO DO WAS VOTE…
# Sentiment(polarity=0.5, subjectivity=1.0)
# RT @JamesMAstill: 86% of the Florida vote in, and Trump leading in Florida by 700 votes. Ye Gods.
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @realDonaldTrump: Don't let up, keep getting out to vote - this election is FAR FROM OVER! We are doing well but there is much time left…
# Sentiment(polarity=0.1625, subjectivity=0.6)
# RT @LaLaSizaHands89: Omw to vote honey!! Yall ready?? I am!! #Vote #VoteOrDie #ImWithHer Song by: @bigfreedia https://t.co/IGHvk2BcA1
# Sentiment(polarity=0.3125, subjectivity=0.5)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/U8U8t9CZCX
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @laureIscastiIlo: me the majority of the election: idk i don't rlly like hillary that much but i guess she has my vote
# me today: https:/…
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @mmpadellan: Wouldn't it be GREAT if @MELANIATRUMP voted for #HRC, and NY became a close race...and Hillary won by ONE VOTE — Melania's?…
# Sentiment(polarity=0.8, subjectivity=0.75)
# RT @MGigger: The irony is not lost on me that the very people who want me to vote for "progress"  in a president want me to farm using 1800…
# Sentiment(polarity=0.2, subjectivity=0.3)
# RT @cajunkallie: Its not over Florida Vote Vote for Trump Vote for America Vote 4 All Americans https://t.co/EWDYszOsvD
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @purebusan: VOTE FOR WHO YA WANT, VOTE FOR HILARY, DO IT FOR DA CLINTONS CLINTONS CLINTONS
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @JayCurvedDaily: "Exercise your right to vote"
# "Your vote can make the difference"
# "every single vote counts"
#
# Electoral College: https…
# Sentiment(polarity=0.10714285714285714, subjectivity=0.375)
# #HillaryClinton casts her vote in #NewYork US election #ElectionNight
# https://t.co/UX9rG1MGxg
# Sentiment(polarity=0.0, subjectivity=0.0)
# 30 VOTE lead Florida!! Go @realDonaldTrump!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @StephenKing: The ugliest election in living memory is almost over, but the polls are still open. VOTE, PEOPLE. Do your job.
# Sentiment(polarity=0.0, subjectivity=0.5)
# I cast my Heisman ballot for Jabrill Peppers! Click the player you think deserves the @NissanUSA #HeismanHouse vote! https://t.co/79lsNwnAsX
# Sentiment(polarity=0.0, subjectivity=0.0)
# @gratefuIdez did u vote?
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Gabbienain: When you trust your wife to vote for you, but not really. https://t.co/tLprW7iXI3
# Sentiment(polarity=-0.1, subjectivity=0.2)
# RT @JSkliasGahan: No stickers left for afternoon voters in my district but I GOT THE SMILE adding my vote for HILLARY! #imwithher ⭐️💃🏻 http…
# Sentiment(polarity=0.1875, subjectivity=0.05)
# RT @JamesOKeefeIII: We just caught election officials telling people who to vote for, crime Under 25 PS 3031.11. I will tag both you and @D…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ElizabethBanks: If you're in line to vote before the polls close, STAY IN LINE to vote! Never give up. Never surrender. Please RT. #Sta…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @CBSNews: Bob Schieffer: "I'm going to go out on a limb here and say most Hispanics are not going to vote for Donald Trump" #Election201…
# Sentiment(polarity=0.5, subjectivity=0.5)
# RT @RealVinnieJames: TRUMP VOTERS: THIS is the image we want to see VERY shortly. Without a CRUSHING WIN she walks. VOTE this vision into r…
# Sentiment(polarity=0.4000000000000001, subjectivity=0.5633333333333334)
# RT @ConnorFranta: task time: text 5 people you know and remind them to vote for Hillary.
# we have the numbers and can do this TOGETHER.
#
# rt…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Had to wait in a 90 minute line to vote to legalize marijuana. You're welcome potheads!!
# Sentiment(polarity=1.0, subjectivity=0.9)
# RT @Sadieisonfire: You 👏 not 👏 allowed 👏 to 👏 vote 👏 until 👏 you 👏 shove 👏 a 👏 whole 👏 8'x12' 👏 American 👏 flag 👏 up 👏 your 👏 ass 👏 first
# Sentiment(polarity=0.15, subjectivity=0.24444444444444446)
# RT @KimberleiDavis: JUST IN: #DonaldTrump will win SC based on exit poll and vote analysis, @ABC News projects. #ElectionNight  https://t.c…
# Sentiment(polarity=0.8, subjectivity=0.4)
# RT @markymark930: how did we let Florida be such an important vote? Florida is literally America's D student.
# Sentiment(polarity=0.2, subjectivity=0.75)
# RT @Zach_Hinchy: How tf do you vote for Hillary Jesus
# Sentiment(polarity=0.0, subjectivity=0.0)
# I cast my Heisman ballot for Lamar Jackson! Click the player you think deserves the @NissanUSA #HeismanHouse vote! https://t.co/4i8Oely2Hg
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...
# RT @DonaldJTrumpJr: College voters might determine this election. Vote for a proven leader, not a corrupt politician. Politicians created t…
# Sentiment(polarity=0.25, subjectivity=1.0)
# RT @badmoonlight: guys dont be dumb, please take voting seriously. do NOT waste your vote like these people. #ElectionDay https://t.co/ne4M…
# Sentiment(polarity=-0.1375, subjectivity=0.25)
# RT @BandzUpDee: Vote Hillary Clinton idc if she a liar y'all boyfriends lie to y'all everyday and y'all still fw them so VOTE HILLARY BITCH…
# Sentiment(polarity=-0.2, subjectivity=0.6)
# RT @MendesArmyMex: Cada rt cuenta.
#
# I vote for @ShawnMendes for New Artist Of The Year Un-Leashed by @TMobile #AMAs
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# RT @Shelovesmeechie: YALL NEED TO VOTE HILLARY BEFORE TRUMP WINS!!!!!! https://t.co/xqQIdmnz8D
# Sentiment(polarity=1.0, subjectivity=0.2)
# RT @Telegraph: In #Florida it's getting VERY tight. With 87% of the vote counted Donald Trump leads Hillary Clinton by just 900 votes #Elec…
# Sentiment(polarity=-0.23214285714285715, subjectivity=0.37142857142857144)
# RT @Jeff__Yang: @realDonaldTrump We are going to stop Trump. VOTE EVERYONE! https://t.co/ndnlsNNHqr
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @RaeSremmurd: 🇺🇸Go vote for her🇺🇸 https://t.co/VSqC8Qpc6S
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @BlissTabitha: BREAKING: Donald Trump Winning Popular Vote 11/8/16 https://t.co/nqrKUG5Q4X
# Sentiment(polarity=0.55, subjectivity=0.825)
# RT @LicensePlateGuy: Can't stand people asking me who'd ya vote for...none of your darn business but I will tell you it was a write in and…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @mspattila: ☎️  TRUMP'S VOTER ASSISTANCE HOTLINE ☎️ 844-332-2016
#
# VOTE UNTIL POLLS CLOSE! ⌛️ DO NOT LISTEN TO MSM LIES ABOUT #CrookedHil…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @onherperiod: rt if u rather vote for a rock
# Sentiment(polarity=0.0, subjectivity=0.0)
# @rickyrozay did you vote nigga?
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @FloridaGOP: America deserves a president that will FIGHT FOR US! Time is running out, vote @realDonaldTrump today! #ElectionDay #VoteTr…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Adolfhibsta: How do black people not find it insulting when candidates use black culture to guilt trip them to vote for them?
# Sentiment(polarity=-0.4444444444444445, subjectivity=0.6222222222222222)
# RT @RaeSremmurd: 🇺🇸Go vote for her🇺🇸 https://t.co/VSqC8Qpc6S
# Sentiment(polarity=0.0, subjectivity=0.0)
# Looks like Florida needs to play a game of fuck marry kill to in order to figure out who to vote for.
# Sentiment(polarity=-0.4, subjectivity=0.5)
# RT @FindlayCourier: 23 percent of Hancock County vote is in; Trump leads by 3,000 votes; Robert Sprague leads by 2-1 margin; Gazarek up 2,0…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @lalalaurennn___: if i can vote for the president of the united states under the age of 21 then i should be able to have a drink to cope…
# Sentiment(polarity=0.5, subjectivity=0.625)
# RT @literallybryan: a vote for trump is actively supporting racism, sexism, homophobia, islamophobia, and disregard for climate change. don…
# Sentiment(polarity=0.25, subjectivity=0.25)
# RT @NasMaraj: If this doesn't make you vote Hillary, I don't know what will. #ImWithHer https://t.co/shQYaBFeGR
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @BernieSanders: I can't fill in for every worker today. Election Day should be a national holiday so that everyone has the opportunity t…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Every vote counts
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @FBCSO: Arrest: We can confirm 1 arrested for attempting to vote a second time. Claimed he worked for Trump and was testing the system.
# Sentiment(polarity=-0.025, subjectivity=0.0)
# RT @ElianaBenador: #URGENT  #FloridaPanhandle #VOTE #TrumpPence16 #ElectionNight #Election2016 https://t.co/h8oqYFO5IL
# Sentiment(polarity=0.0, subjectivity=0.0)
# Colin Kaepernick didn't vote! He said, "Don't vote against your consciousness!" I knew I wasn't crazy. Somebody give this man an award!
# Sentiment(polarity=-0.75, subjectivity=0.9)
# @ThatgirlO_o did you early vote?
# Sentiment(polarity=0.1, subjectivity=0.3)
# @TheTorontoSun @CandiceMalcolm Trudeau is nothing but a liar... will say anything to win a vote... a demagogue... #wakeupcanada
# Sentiment(polarity=0.8, subjectivity=0.4)
# RT @epDannyEdge: make america great again..
#
# ..
#
# ...
#
# ....
#
# VOTE FOR PEDRO!!! https://t.co/7qQ6ORYiNa
# Sentiment(polarity=1.0, subjectivity=0.75)
# Dear god every republican in Florida better get their ass out &amp; vote in the next 20 min
# Sentiment(polarity=0.25, subjectivity=0.25)
# RT @BDinSA: HRC ahead 53.46 % to Trump's 41.38 % in Bexar early vote. #Election2016
# Sentiment(polarity=0.1, subjectivity=0.3)
# HEY WHERE ARE ALL THE PEOPLE CLAIMING VOTING THIRD PARTY IS THROWING YOUR VOTE AWAY ABOUT JOHNSON VOTERS IN FLORIDA… https://t.co/iVDVvBPGi4
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @igorvolsky: At least of the victims was headed to the polling station to vote, a law enforcement source said #Azusa https://t.co/VR6FBr…
# Sentiment(polarity=-0.3, subjectivity=0.4)
# RT @jamesmichael: s/o to this golden moment where Trump let us all know that he doubted his own wife would vote for him. https://t.co/rDdUt…
# Sentiment(polarity=0.44999999999999996, subjectivity=0.75)
# RT @marskesum: Everyone down in Florida VOTE FOR TRUMP
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# RT @LaurenJauregui: I'm so excited that I was able to exercise my vote as a Cuban American Woman for the first time in this particular elec…
# Sentiment(polarity=0.25833333333333336, subjectivity=0.4083333333333333)
# RT @RANsquawk: #Florida (87% having reported): Clinton 48.5% vs. Trump 48.5% - only 1600 vote gap between the two!
# Sentiment(polarity=0.0, subjectivity=1.0)
# @ABC7Chicago vote!!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ScottWesterfeld: IF YOU
#     💁🏼
# ARE IN LINE
#  🚶🏾🚶🏾🚶🏾🚶🏾🚶🏾🚶🏾🚶🏾
# WHEN THE POLLS
# CLOSE
#   🗝
# THEY
#   👮🏽👮🏻
# ARE LEGALLY REQUIRED
#   ⚖⚖⚖⚖
# TO LET YOU…
# Sentiment(polarity=0.2, subjectivity=0.2)
# couldn't in good conscious vote for either of those baboons.
# Sentiment(polarity=0.39999999999999997, subjectivity=0.55)
# I just told @nbcwashington who I think is winning. Cast your vote now! #Debates #NBC4DC https://t.co/eCBA2E1LRq
# Sentiment(polarity=0.625, subjectivity=0.75)
# RT @kwmvp: @Nanette4CA took the family with me to vote. We have placed our faith in you. Do right by us please! Good luck! https://t.co/MUk…
# Sentiment(polarity=0.6160714285714286, subjectivity=0.5678571428571428)
# RT @_Latishhaaaa: I got a lump in my throat as I watched this , President Obama , you will be truly missed 😭😭 Continue his legacy , GO VOTE…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @h_squared9: Look at the vote count in Florida right now and tell me your vote doesn't matter.
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# RT @seanhannity: .@realDonaldTrump joined me on radio with an important reminder - make sure to get out and vote! https://t.co/YLhNc4TJmU
# Sentiment(polarity=0.5125, subjectivity=0.9444444444444444)
# EVERY VOTE COUNTS! https://t.co/GMOVeZ4gWN
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Gabbienain: When you trust your wife to vote for you, but not really. https://t.co/tLprW7iXI3
# Sentiment(polarity=-0.1, subjectivity=0.2)
# RT @VOANews: Here's the current electoral vote map:
# Clinton: 75
# Trump: 56
# #Elections2016 https://t.co/vMVF5xAxsc
# Sentiment(polarity=0.0, subjectivity=0.4)
# RT @CloydRivers: To everyone who wants to vote for Hillary just to keep Trump from becomin' President, watch this...
# https://t.co/TuUpD7Qgcg
# Sentiment(polarity=0.2, subjectivity=0.1)
# RT @MartinOMalley: Hey Maryland: Polls are open til 8pm. Let's beat that fascist  @realdonaldtrump w/ the largest vote margin for @hillaryc…
# Sentiment(polarity=0.0, subjectivity=0.5)
# RT @EC__82: I voted today! Go vote! Write in @officialKeef @RollingStones #KeithRichards4president https://t.co/G6gK1oGiQd
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @lemonadenormani: Get out and vote tomorrow for @HillaryClinton! #ImWithHer #ThatsMyGirlHillary https://t.co/r8JFMhIJA0
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Vailskibum94: Can we please vote him instead?! https://t.co/ce6sYciFPp
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @HillaryforNC: If you haven't voted, NC, @POTUS needs you to get in line. As long as you're in line when polls close, you can vote. http…
# Sentiment(polarity=-0.05, subjectivity=0.4)
# I vote that Danny Coale caught that ball and so can you. #ElectionDay
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @BlogsofWar: When you suspect bae might not actually vote for you on #ElectionDay https://t.co/r6q4TvOII6
# Sentiment(polarity=0.0, subjectivity=0.1)
# RT @NoHoesGeorge: Vote Corey back in the house
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @nailogical: Now u can vote AND enter my late AF 2M sub giveaway! Wow, what a day
# GIVEAWAY VIDEO: https://t.co/tc3XzUo89w watch to enter…
# Sentiment(polarity=-0.1375, subjectivity=0.8)
# RT @HillaryClinton: Remember, if you are in line before polls close, you can vote! Have a question? Call 1-917-444-5915. https://t.co/2MVKO…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @NiallOfficial: Wish I could vote today .. America get out and vote and do the right thing please
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# RT @thehill: JUST IN: Trump supporter arrested after trying to vote twice to ‘test the system’ https://t.co/4ZDFOHdnYs https://t.co/a62kxGm…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @obeyingjauregui: Imagine being so immature and taking your vote for granted like this when there are people out there wishing they coul…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @HillaryClinton: Remember, if you are in line before polls close, you can vote! Have a question? Call 1-917-444-5915. https://t.co/2MVKO…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @HereIsGina: STAY IN LINE. MY PEOPLE. MY WARRIORS.  IF YOU ARE IN LINE TO VOTE, STAY IN LINE.
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @DepressedDarth: Vote for me and together we can rule the galaxy #ElectionNight https://t.co/isfFH8hxLA
# Sentiment(polarity=0.0, subjectivity=0.0)
# At least they're reducing trumps vote 🙃🙃 https://t.co/knZNH5OQx2
# Sentiment(polarity=-0.3, subjectivity=0.4)
# RT @DrPresidentPat: DONALD TRUMP'S SON MAY HAVE JUST DISQUALIFIED HIS VOTE FOR HIS OWN FATHER I CANNOT BREATHE IMAGINE BEING THIS DUMB http…
# Sentiment(polarity=0.11249999999999999, subjectivity=0.75)
# Literally 30 vote difference for Florida
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Telegraph: In #Florida it's getting VERY tight. With 87% of the vote counted Donald Trump leads Hillary Clinton by just 900 votes #Elec…
# Sentiment(polarity=-0.23214285714285715, subjectivity=0.37142857142857144)
# RT @KaylinCharmaine: "Black folks didn't die for the right to vote. They died for freedom. Voting is just a tact for that." -@marclamonthill
# Sentiment(polarity=0.05952380952380952, subjectivity=0.4845238095238095)
# More like this! Please. For the world. #ElectionNight #vote https://t.co/aVJNUEWgWi
# Sentiment(polarity=0.625, subjectivity=0.5)
# RT @iam8bit: HEY YOU!! You better VOTE TODAY!!! @HillaryClinton by @nerdlyart https://t.co/dPMjAAegQN https://t.co/RPDVjAcA1r
# Sentiment(polarity=0.9765625, subjectivity=0.5)
# RT @antdude92: Remember to go out and vote. https://t.co/0C5ASDIkRH
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @RevDrBarber: BREAKING: Voting has been extended in Columbus and Durham. Stay in line. Don't get discouraged. Vote! Vote! VOTE! #webette…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @realDonaldTrump: Don't let up, keep getting out to vote - this election is FAR FROM OVER! We are doing well but there is much time left…
# Sentiment(polarity=0.1625, subjectivity=0.6)
# RT @whytruy: *casts vote for Hillary*
# Hillary: Thank you for your vot-
# Me: https://t.co/EjvxMWZD2c
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Gabbienain: When you trust your wife to vote for you, but not really. https://t.co/tLprW7iXI3
# Sentiment(polarity=-0.1, subjectivity=0.2)
# RT @ThisDopeKid: THIS IS WHY YOU GUYS SHOULD VOTE FOR HILLARY https://t.co/EQzgVCIhwa
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Joshuacole__: Me trying to vote more than once so Trump doesn't win https://t.co/zosWajAi3d
# Sentiment(polarity=0.65, subjectivity=0.45)
# RT @jaureologist: I DON'T CARE HOW MUCH Y'ALL HATE BOTH CANDIDATES YOU WILL VOTE FOR HILLARY WHETHER YOU LIKE IT OR NOT I REFUSE TO LET TRU…
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.55)
# First we vote, then we pray. #election2016 #elcavotes #mosaicpossible https://t.co/oDDJDd3r4A https://t.co/8VA2R1ag8s
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Current Electoral Vote Count: Hillary Clinton 68, Donald Trump 57. 270 votes needed to... https://t.co/BHWUfhkrto by #CBS11 via @c0nvey
# Sentiment(polarity=0.0, subjectivity=0.4)
# RT @shakira: The Latino vote can help decide the fate of a nation and the world's, don't stand still vote now! Shak
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @_carolineotoole: If you vote Trump tomorrow, make sure explain to your gay, trans, female, black, Latina/o, and Muslim friends why they…
# Sentiment(polarity=0.18750000000000003, subjectivity=0.5180555555555556)
# RT @NoHoesGeorge: Vote Corey back in the house
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @DepressedDarth: Vote for me and together we can rule the galaxy #ElectionNight https://t.co/isfFH8hxLA
# Sentiment(polarity=0.0, subjectivity=0.0)
# If trump wins I'm unfriending everyone who didn't vote of voted third party how dare you risk other people's rights
# Sentiment(polarity=0.05833333333333333, subjectivity=0.19166666666666665)
# RT @CauseWereGuys: when you trust your wife to vote for you, but not really. https://t.co/KgK91R5kbW
# Sentiment(polarity=-0.1, subjectivity=0.2)
# I wish I was old enough to vote... #ElectionNight
# Sentiment(polarity=0.05, subjectivity=0.35)
# RT @xojasmyn_: Trump won the majority vote in Cumberland so there's that...
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @laureIscastiIlo: me the majority of the election: idk i don't rlly like hillary that much but i guess she has my vote
# me today: https:/…
# Sentiment(polarity=0.2, subjectivity=0.2)
# So glad I could vote 👍🏾🇺🇸 https://t.co/YCxgyfDqkG
# Sentiment(polarity=0.5, subjectivity=1.0)
# RT @JanelleMonae: Some people like watching train wrecks. I@am@not one of them. Trump is still leading with electoral votes. This is not fu…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Older white male polices immigrant's vote.  @zekejwilliams gets the credit! https://t.co/031kR0Z1nk
# Sentiment(polarity=0.05555555555555555, subjectivity=0.14444444444444446)
# RT @JohnEdwards33: Respect women?
# Doesn't even trust his wife to vote for him..
#
#  https://t.co/MCjYh3GyUj via @youtube
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @EricTrump: Join my family in this incredible movement to #MakeAmericaGreatAgain!! Now it is up to you! Please #VOTE for America! https:…
# Sentiment(polarity=1.0, subjectivity=0.9)
# Leslie Knope would vote for Hillary Clinton please remember that please do not vote for the racist gourd please do not vote for Jeremy Jamm
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @whytruy: *casts vote for Hillary*
# Hillary: Thank you for your vot-
# Me: https://t.co/EjvxMWZD2c
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @jack_p: Hey America, GO VOTE.
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @nycjim: With 83 percent of the vote in, Clinton has a slim lead in Florida. https://t.co/yzQb9duksG https://t.co/XAnqc02BOK
# Sentiment(polarity=0.0, subjectivity=0.0)
# Yay, the Florida margin is tiny compared to the Jill Stein vote.
# Sentiment(polarity=0.0, subjectivity=0.5)
# A general view of 'Vote No on 2 Bad for Public Schools ' watch party at The Fairmont Copley Plaza#buvote16… https://t.co/zCoMNw7Vyg
# Sentiment(polarity=-0.2166666666666666, subjectivity=0.41111111111111104)

# %%
def calc_sqrt(t):
    r = t/2.0
    print r
    t = float(t)
    i = 0
    while i < 10:
        r = (r+t/r)/2
        print r
        i += 1
    return r

# %%
calc_sqrt(100)
# Out:
# 50.0
# 26.0
# 14.9230769231
# 10.8120539255
# 10.0304952039
# 10.0000463565
# 10.0000000001
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0

# %%
import vincent
 
word_freq = count_terms_only.most_common(20)
labels, freq = zip(*word_freq)
data = {'data': freq, 'x': labels}
bar = vincent.Bar(data, iter_idx='x')
bar.to_json('term_freq.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9ff86d98d47d> in <module>()
#       1 import vincent
#       2
# ----> 3 word_freq = count_terms_only.most_common(20)
#       4 labels, freq = zip(*word_freq)
#       5 data = {'data': freq, 'x': labels}
#
# NameError: name 'count_terms_only' is not defined

# %%
#!/usr/bin/env python

import tweepy
# ckey = 'xxx'
# csecret = 'xxx'
# atoken = 'xxx'
# asecret = 'xxx'


# auth = tweepy.OAuthHandler(ckey, csecret)
# auth.set_access_token(atoken, asecret)

# api = tweepy.API(auth)

tweets = []                             # You pass this array to the Bayesian Classifier
for tweet in tweepy.Cursor(api.search,
                       q="vote",
                       result_type="recent",
                       include_entities=True,
                       lang="en").items(10):
    print tweet.created_at, tweet.text  
    tweets.append(tweet.text)           # Store the tweets in your array

# %%
tweets
